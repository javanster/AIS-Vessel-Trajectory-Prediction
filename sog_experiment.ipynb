# %%
import pandas as pd
from tqdm import tqdm


train_df = pd.read_csv('data/processed_data/train.csv')
test_df = pd.read_csv('data/processed_data/test.csv')
vessels_df = pd.read_csv('data/processed_data/vessels.csv')

# %%
vessels_df.head()
# Out:
#              shippingLineId  vesselId   CEU      DWT     GT       NT  \
# 0  61a8e672f9cba188601e84ab  0.000000  6500  21200.0  58684  17606.0
# 1  61ec94f1a8cafc0e93f0e92a  0.001389  4902  12325.0  46800      NaN
# 2  61e213d5d612676a0f0fb755  0.002778  5000  13059.0  46800      NaN
# 3  61be24574ea00ae59d0fe388  0.004167  4200  12588.0  39362      NaN
# 4  61a8e673f9cba188601e84ae  0.005556  7450  21052.0  75528  24391.0
#
#    vesselType  breadth  depth  draft  enginePower  freshWater     fuel  \
# 0        83.0     32.0  22.20    NaN          0.0         NaN      NaN
# 1        83.0     31.0    NaN    NaN      14220.0         NaN      NaN
# 2        83.0     31.0    NaN    NaN      14220.0         NaN      NaN
# 3        83.0     28.0    NaN    NaN      11060.0         NaN      NaN
# 4        83.0     37.2  22.23    NaN      13140.0      491.47  3236.78
#
#        homePort  length  maxHeight  maxSpeed  maxWidth  rampCapacity  \
# 0          OSLO  199.00        5.0      18.6      15.2         150.0
# 1      MONROVIA  182.00        NaN       NaN       NaN           NaN
# 2  SAINT JOHN'S  182.00        NaN       NaN       NaN           NaN
# 3           NaN  167.00        NaN       NaN       NaN           NaN
# 4        Panama  199.98        NaN       NaN       NaN           NaN
#
#    yearBuilt
# 0       2000
# 1       2006
# 2       2010
# 3       2011
# 4       2018
